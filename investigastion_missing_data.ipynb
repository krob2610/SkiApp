# %%
import pandas as pd

timestamp_ns = 1704002234850176800
datetime = pd.to_datetime(timestamp_ns, unit='ns')

print(datetime)
# Out:
# 2023-12-31 05:57:14.850176800

# %%
pd.to_datetime(1707348417844498700, unit='ns')
# Out:
# Timestamp('2024-02-07 23:26:57.844498700')

# %%
pd.to_datetime(1707348413111002000, unit='ns')
# Out:
# Timestamp('2024-02-07 23:26:53.111002')

# %%
df = pd.read_csv('/Users/kuba/SkiApp/data/2024-01-05/HUAWEI_Y7/final_df.csv')

# %%
df2 = pd.read_csv('/Users/kuba/SkiApp/data/2024-01-05/HONOR_8X/final_df.csv')

# %%
df
# Out:
#                           time  \
# 0      2024-01-05 10:04:45.000
# 1      2024-01-05 10:04:45.100
# 2      2024-01-05 10:04:45.200
# 3      2024-01-05 10:04:45.300
# 4      2024-01-05 10:04:45.400
# ...                        ...
# 78581  2024-01-05 18:51:30.500
# 78582  2024-01-05 18:51:30.600
# 78583  2024-01-05 18:51:30.700
# 78584  2024-01-05 18:51:30.800
# 78585  2024-01-05 18:51:30.900
#
#                                        TotalAcceleration  \
# 0      [8.806367874145508, 3.4676284790039062, -3.477...
# 1      [8.916200637817383, 3.7657546997070312, -1.688...
# 2      [8.947587966918945, 4.973930358886719, -0.1353...
# 3      [7.59819221496582, 5.601570129394531, 0.759039...
# 4      [8.696535110473633, 4.267845153808594, 0.20986...
# ...                                                  ...
# 78581  [9.088808059692385, 1.9299545288085933, -1.971...
# 78582  [10.579408645629885, 1.7730484008789062, -1.50...
# 78583  [9.010347366333008, 2.0083999633789062, -1.578...
# ...

# %%
df2
# Out:
#                            time  \
# 0       2024-01-05 10:04:14.600
# 1       2024-01-05 10:04:14.700
# 2       2024-01-05 10:04:14.800
# 3       2024-01-05 10:04:14.900
# 4       2024-01-05 10:04:15.000
# ...                         ...
# 317052  2024-01-05 18:52:39.800
# 317053  2024-01-05 18:52:39.900
# 317054  2024-01-05 18:52:40.000
# 317055  2024-01-05 18:52:40.100
# 317056  2024-01-05 18:52:40.200
#
#                                         TotalAcceleration  \
# 0       [8.548688888549805, 4.976655006408691, -1.4470...
# 1       [8.338459014892578, 5.12942361831665, -1.84157...
# 2       [8.095149993896484, 4.502679347991943, -0.6798...
# 3       [10.179466247558594, 4.922909736633301, -2.041...
# 4       [8.688213348388672, 4.830043315887451, -1.2286...
# ...                                                   ...
# 317052  [10.139894485473633, 3.6111457347869873, 0.574...
# 317053  [9.722431182861328, 3.0926287174224854, 0.4315...
# ...
